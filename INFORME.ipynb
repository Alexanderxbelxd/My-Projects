# %% [markdown]
# CORTE 3- ACTIVIDAD 1
#
# Utilizando la libreria de Python -> Matplotlib generar un informe visual con los resultados de las elecciones presidenciales en Colombia.
#
#
#
# En este informe encontraremos especificaciones tanto Graficas, Como escritas sobre los Resultados de las elecciones presidenciales en Colombia el pasado 19 de junio de 2022.
#
# Porcentaje De Votos En Estas Elecciones:

# %% [markdown]
# Mesas Informadas
#
# 103.364 de 103.364

# %%
import matplotlib.pyplot as plt 

etiquetas = ["Mesas Informadas"]
valores = [103364]
colores =["royalblue"]

plt.pie(x=valores, labels=etiquetas, colors= colores, autopct='%1.2f%%')
plt.title ("Mesas Informadas 100%")
plt.show()

# %% [markdown]
# Votantes
#
# 22.658.694 de 39.002.239

# %%
import matplotlib.pyplot as plt 

etiquetas = ["Votantes", "Posibles Votantes"]
valores = [22658694, 39002239]
colores =["aquamarine", "silver"]

plt.pie(x=valores, labels=etiquetas, colors= colores, autopct='%1.2f%%')
plt.title ("Votantes")
plt.show()

# %%
import matplotlib.pyplot as plt 

etiquetas = ["No Marcados","A Candidatos", "Nulos", "Validos", "En Blanco"]
valores = [23615,21861425, 271667, 22363412, 501987]
colores =["cadetblue", "cyan", "gold", "teal", "red"]

plt.pie(x=valores, labels=etiquetas, colors= colores, autopct='%1.2f%%')
plt.title ("INFORMACION GENERAL ELECCIONES PRESIDENCIALES 2022")
plt.show()

# %% [markdown]
# Ahora veremos los resultados de manera general entre El partido Coalicion Pacto Historico Y El partido Liga De Gobernantes Anticorrupcion:

# %%
import matplotlib.pyplot as plt 

etiquetas = ["Liga De Gobernantes Anticorrupcion", "Pacto Historico"]
valores = [10580412, 11281013]
colores = ["royalblue", "gold"]

plt.pie(x=valores, labels=etiquetas, colors= colores, autopct='%1.2f%%')
plt.title ("RESULTADOS GENERALES ELECCIONES PRESIDENCIALES 2022")
plt.show()

# %% [markdown]
# A Continuacion se podra evidenciar los Departamentos a favor del Partido Coalicion Pacto Historico a cargo de GUSTAVO PETRO Y FRANCIA MARQUEZ MINA

# %%
import matplotlib.pyplot as plt

eje_x = ["Amazonas", "Atlantico", "Bogota","Bolivar", "Cauca", "Cesar" , "Choco","Cordoba", "Guainia","La Guajira", "Magdalena","Nariño","Putumayo" ,"San Andres", "Sucre","Valle", "Vaupes"] 
eje_y = [ 12883 , 672832, 2253997,493041,515074, 250499,127846,437016, 6536, 162849, 302439,592170,110118, 8545, 262135, 1310236, 6447 ]

plt.barh(eje_x,eje_y, color="limegreen")
plt.ylabel("Departamento")
plt.xlabel("Numero De Votaciones")
plt.title("Departamentos A Favor Del Partido Coalicion Pacto Historico  ")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# A Continuacion se podra evidenciar los Departamentos a favor del Partido Liga De Gobernantes Anticorrupcion a cargo de  RODOLFO HERNÁNDEZ Y MARELEN CASTILLO

# %%
import matplotlib.pyplot as plt

eje_x = ["Antioquia","Arauca", "Boyaca", "Caldas", "Caqueta", " CASANARE","Consulados", "Cundinamarca","Guaviare", "Huila", "Meta","Norte De Santander", "Quindio","Risaralda","Santander" , "Tolima","Vichada" ] 
eje_y = [ 1822700 , 69473 , 378899,267988, 88922,  143796 , 185557, 756454, 17601, 305799,307137, 557406, 151653,  238963,871291, 388640,11447 ]

plt.barh(eje_x,eje_y, color="limegreen")
plt.ylabel("Departamento")
plt.xlabel("Numero De Votaciones")
plt.title("Departamentos A Favort Del Partido Liga De Gobernantes Anticorrupcion")
plt.show
# Out:
# <function matplotlib.pyplot.show>
